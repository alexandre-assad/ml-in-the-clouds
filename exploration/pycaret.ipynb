# %%
from pandas import read_csv
from pycaret.classification import setup, compare_models, save_model, predict_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from pandas import read_csv
#       2 from pycaret.classification import setup, compare_models, save_model, predict_model
#
# ModuleNotFoundError: No module named 'pandas'

# %%
dataframe = read_csv('../data/emotions.csv')
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52821 entries, 0 to 52820
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  52821 non-null  int64
#  1   text        52821 non-null  object
#  2   emotion     52821 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ MB

# %%
clf = setup(
    data=df,
    target='emotion',
    session_id=123,
    preprocess=True,
    text_features=['text'],  # NLP automatique
    n_jobs=-1,
    verbose=True,
    imputation_type=None  # PyCaret gère tout seul sauf si tu veux configurer
)
